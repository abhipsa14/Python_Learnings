# %% [markdown]
# ### Standard libraries
# It is a vast collection of modules and packages that come bundled with Python, providing a wide range of functionalities out of the box.

# %%
import array
arr = array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
## random
import random
print(random.randint(1,10))
print(random.choice(['abhipsa','anshika','alok','bina']))
# Out:
# 4
# alok

# %%
## fiel and directory
import os
print(os.getcwd())
# Out:
# c:\Users\abhip\Desktop\learnings\Python_Learnings\4. Modules

# %%
os.mkdir('test_dir/hi.txt')

# %%
## high level operation on file and collection of files
import shutil
shutil.copyfile('source.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
## data serialization
import json
data={'name':'abhi','age':35}
json_str=json.dumps(data)
print(json_str)
print(type(json_str))
parsed_data=json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "abhi", "age": 35}
# <class 'str'>
# {'name': 'abhi', 'age': 35}
# <class 'dict'>

# %%
## csv
import csv
with open('example.csv',mode='w',newline='') as file:
    writer=csv.writer(file)
    print(dir(writer))
    writer.writerow(['name','age','occupation'])
    writer.writerows([['abhi',21,'engineer'],['anshika',22,'designer'],['alok',23,'manager'],['bina',24,'analyst']])
with open('example.csv',mode='r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'dialect', 'writerow', 'writerows']
# ['name', 'age', 'occupation']
# ['abhi', '21', 'engineer']
# ['anshika', '22', 'designer']
# ['alok', '23', 'manager']
# ['bina', '24', 'analyst']

# %%
## datetime
from datetime import datetime, timedelta
now=datetime.now()
print(now)
yesterday=now-timedelta(days=1)
print(yesterday)
# Out:
# 2026-04-04 14:18:01.076362
# 2026-04-03 14:18:01.076362

# %%
## time
import time
print(round(time.time(),2))
time.sleep(10)
print(round(time.time(),2))
# Out:
# 1775292552.54
# 1775292562.54

# %%
## regular expression
import re
pattern=r'\d+' ## integer pattern
text='There are 123 apples'
match=re.search(pattern,text)
print(match.group())
# Out:
# 123
