# %% [markdown]
# ### Iterators
# - They are advanced python concepts that allow for efficient looping and memory management
# - They provide a way to access elements of a collection sequentially without exposing the underlying structure.

# %%
my_list=[1,2,3,4,5]
for i in my_list:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
type(my_list)
# Out:
# list

# %%
## iterator
iterator=iter(my_list)
print(type(iterator))
# Out:
# <class 'list_iterator'>

# %%
iterator

# %%
## iterate through all the elements
next(iterator)
# Out:
# 1

# %%
iterator=iter(my_list)

# %%
try:
    print(next(iterator))
except StopIteration:
    print("There are no elements in the iterator")
# Out:
# 1

# %%
## string iterator 
my_string ="Hello"
string_iterator=iter(my_string)

print(next(string_iterator))
print(next(string_iterator))
# Out:
# H
# e

# %%
print(string_iterator.__next__)
# Out:
# <method-wrapper '__next__' of str_ascii_iterator object at 0x000001678D574F40>
