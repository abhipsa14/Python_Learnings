# %% [markdown]
# ### Exception Handling
# Exception handling in python allows you to handle errors gracefully and take corrective actions without stopping the execution of the program. You can use `try`, `except`, `else`, and `finally` blocks to manage exceptions.

# %% [markdown]
# Exceptions are events that disrupt the normal flow of a program. They occur when an error is encountered during program execution. Common exceptions include:
#
# - ZeroDivisionError: Dividing by zero
# - FileNotFoundError: File not found
# - ValueError: Invalid value
# - TypeError: Invalid type

# %%
a=b ## name error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 a=b
#
# NameError: name 'b' is not defined

# %%
## exception try, except block
try:
    a=b
except:
    print("The varibale has not been assigned")
# Out:
# The varibale has not been assigned

# %%
## exception try, except block
try:
    a=b
except NameError as ex: ## defining the exception as ex
    print(ex)
# Out:
# name 'b' is not defined

# %%
result=1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 result=1/0
#
# ZeroDivisionError: division by zero

# %%
try:
    result=1/0
except ZeroDivisionError as ex:
    print(ex)
# Out:
# division by zero

# %%
try:
    result=1/2
    a=b ## not handled
except ZeroDivisionError as ex:
    print(ex)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 try:
#       2     result=1/2
# ----> 3     a=b ## not handled
#       4 except ZeroDivisionError as ex:
#       5     print(ex)
#
# NameError: name 'b' is not defined

# %%
try:
    result=1/2
    a=b
except ZeroDivisionError as ex:
    print(ex)
except Exception as ex1:
    print(ex1)
# Out:
# name 'b' is not defined

# %%
try:
    num=int(input("Enter a number"))
    result=10/num
except ValueError:
    print("This is not valid number")
except ZeroDivisionError:
    print("Enter denominator greater than 0")
except Exception as ex:
    print(ex)

# %%
## try, except, else
try:
    num=int(input("Enter a number:"))
    result=10/num
except ValueError:
    print("enter valid number")
except ZeroDivisionError:
    print("division by zero")
else: ## it will get executed only when there is no exception
    print(f"the result is {result}")
# Out:
# the result is 2.5

# %%
## try,except,else and finally
try:
    num=int(input("Enter a number:"))
    result=10/num
except ValueError:
    print("valid number")
except ZeroDivisionError:
    print("division by zero")
else:
    print(f"the result is {result}")
finally: ## it will always executed
    print("execution complete")
# Out:
# division by zero
# execution complete

# %%
## file handling and exception handling
try:
    file=open("examples.txt",'r')
    content=file.read()
except FileNotFoundError:
    print("not found")
else:
    print(content)
finally:
    if ('file' in locals()) and (not file.closed):
        file.close()
        print('file close')
# Out:
# hello
# i am abhipsa
#
# file close

# %%
## file handling and exception handling
try:
    file=open("examples1.txt",'r')
    content=file.read()
except FileNotFoundError:
    print("not found")
else:
    print(content)
finally:
    if ('file' in locals()) and (not file.closed):
        file.close()
        print('file close')
# Out:
# not found
