# %% [markdown]
# ### Variable Scope

# %%
# age=9

def test():
    print(age)


print(age)
test()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       3 def test():
#       4     print(age)
# ----> 7 print(age)
#       8 test()
#
# NameError: name 'age' is not defined

# %%
def test():
    print(age)


print(age)
test()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       1 def test():
#       2     print(age)
# ----> 5 print(age)
#       6 test()
#
# NameError: name 'age' is not defined

# %%
name="Kumar"

def test(): 
    name="Abhip"
    print(name)
test()
print(name)
# Out:
# Abhip
# Kumar
