# %% [markdown]
# ## Multithreading

# %%
import threading

# %%
def test(id):
    print("this is my test id %d" % id)

# %%
test(10)
test(1)
test(3)
# Out:
# this is my test id 10
# this is my test id 1
# this is my test id 3

# %%
thread=[threading.Thread(target=test, args=(i,)) for i in [10,1,3]]

# %%
thread
# Out:
# [<Thread(Thread-12 (test), initial)>,
#  <Thread(Thread-13 (test), initial)>,
#  <Thread(Thread-14 (test), initial)>]

# %%
for t in thread:
    t.start()
# Out:
# this is my test id 10
# this is my test id 1
# this is my test id 3

# %%
import urllib.request
def file_download(url, filename):
    urllib.request.urlretrieve(url, filename)

# %%
file_download('https://raw.githubusercontent.com/itsfoss/text-files/master/agatha.txt', "test1.txt")

# %%
url_list = ['https://raw.githubusercontent.com/itsfoss/text-files/master/agatha.txt' , 'https://raw.githubusercontent.com/itsfoss/text-files/master/sherlock.txt' ,'https://raw.githubusercontent.com/itsfoss/text-files/master/sample_log_file.txt' ]

# %%
url_list
# Out:
# ['https://raw.githubusercontent.com/itsfoss/text-files/master/agatha.txt',
#  'https://raw.githubusercontent.com/itsfoss/text-files/master/sherlock.txt',
#  'https://raw.githubusercontent.com/itsfoss/text-files/master/sample_log_file.txt']

# %%
data_file_list=['data1.txt','data2.txt','data3.txt']

# %%
data_file_list
# Out:
# ['data1.txt', 'data2.txt', 'data3.txt']

# %%
thread1=[threading.Thread(target=file_download,args=(url_list[i],data_file_list[i])) for i in range(len(url_list))]

# %%
for t in thread1:
    t.start()

# %%
thread1
# Out:
# [<Thread(Thread-49 (file_download), stopped 4696)>,
#  <Thread(Thread-50 (file_download), stopped 1532)>,
#  <Thread(Thread-51 (file_download), stopped 19640)>]

# %%
import time

def test2(x):
    for i in range(10):
        print("test2 print the value of x %d and print the value of i %d " %(x,i))
        time.sleep(1)
